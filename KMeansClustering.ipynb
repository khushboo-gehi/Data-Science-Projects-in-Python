# %% [markdown]
# <a href="https://colab.research.google.com/github/khushboo-gehi/Data-Science-Projects-in-Python/blob/main/KMeansClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lithion power, drivers incentivization using KMeans Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=(12,6)

# %%
df = pd.read_csv('/content/Demo Datasets/Lesson 7/driver-data.csv')
df.head()
# Out:
#            id  mean_dist_day  mean_over_speed_perc
# 0  3423311935          71.24                    28
# 1  3423313212          52.53                    25
# 2  3423313724          64.54                    27
# 3  3423311373          55.69                    22
# 4  3423310999          54.58                    25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4000 non-null   int64
#  1   mean_dist_day         4000 non-null   float64
#  2   mean_over_speed_perc  4000 non-null   int64
# dtypes: float64(1), int64(2)
# memory usage: 93.9 KB

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2)
df_analyze = df.drop('id',axis=1)

# %%
kmeans.fit(df_analyze)
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 50.04763438,   8.82875   ],
#        [180.017075  ,  18.29      ]])

# %%
print(kmeans.labels_)
# Out:
# [0 0 0 ... 1 1 1]

# %%
print(kmeans.labels_)
print(len(kmeans.labels_))
# Out:
# [0 0 0 ... 1 1 1]
# 4000

# %%
print(type(kmeans.labels_))
unique,counts = np.unique(kmeans.labels_,return_counts=True)
print(dict(zip(unique,counts)))
# Out:
# <class 'numpy.ndarray'>
# {0: 3200, 1: 800}

# %%
df_analyze['cluster']=kmeans.labels_
sns.set_style('whitegrid')
sns.lmplot('mean_dist_day','mean_over_speed_perc', data=df_analyze, hue='cluster', palette='coolwarm',size=6,aspect=1, fit_reg=False)

# %%
kmeans_4 = KMeans(n_clusters=4)
kmeans_4.fit(df.drop('id', axis=1))
kmeans_4.fit(df.drop('id', axis=1))
print(kmeans_4.cluster_centers_)
unique,counts = np.unique(kmeans_4.labels_,return_counts=True)

kmeans_4.cluster_centers_
print(dict(zip(unique,counts)))
# Out:
# [[180.34311782  10.52011494]
#  [ 49.98428468   5.21441441]
#  [177.83509615  70.28846154]
#  [ 50.46127059  32.42823529]]
# {0: 696, 1: 2775, 2: 104, 3: 425}

# %%
df_analyze['cluster']=kmeans_4.labels_
sns.set_style('whitegrid')
sns.lmplot('mean_dist_day','mean_over_speed_perc', data=df_analyze, hue='cluster', palette='coolwarm',size=6,aspect=1, fit_reg=False)
